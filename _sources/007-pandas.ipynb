# %% [markdown]
# # Pandas
#
# Pandas allows for the manipulation of tabular data (i.e. organized as rows and columns) in a data structure known as
# a ``dataframe``. While you may at times need to create such a structure yourself, very often you will read in the
# data for the dataframe from a file such as a CSV file. (Many other file types are supported, such as Parquet, )

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read in a dataframe and display it

# %%
df = pd.read_csv('assets/pandas-example.csv')
df
# Out:
#         Name       City  Birth Year Favorite Color Country of Birth  \
# 0      Alice   New York        1990           Blue              USA
# 1        Bob     London        1985          Green               UK
# 2    Charlie      Paris        1992            Red           France
# 3      David      Tokyo        1988         Indigo            Japan
# 4        Eve   New York        1991         Violet              USA
# 5      Frank     Berlin        1983         Orange          Germany
# 6      Grace     London        1987         Yellow               UK
# 7      Heidi      Paris        1994           Blue           France
# 8       Ivan   New York        1980          Green              USA
# 9       Judy      Tokyo        1989            Red            Japan
# 10     Kevin     Berlin        1993         Orange          Germany
# 11      Liam     London        1986         Yellow               UK
# 12       Mia   New York        1995          Green              USA
# 13      Noah      Paris        1982           Blue           France
# 14    Olivia      Tokyo        1990         Indigo            Japan
# 15     Peter     Berlin        1984         Violet          Germany
# 16     Quinn     London        1992            Red               UK
# 17     Rahul     Mumbai        1981         Orange            India
# 18       Mei   Shanghai        1990         Yellow            China
# 19      Sven  Stockholm        1987          Green           Sweden
# 20     Priya     Mumbai        1989           Blue            India
# 21     Arjun     Mumbai        1993         Indigo            India
# 22  Giuseppe       Rome        1986         Violet            Italy
#
#            Profession         Hobbies      Pet  Height (cm)  \
# 0   Software Engineer          Hiking      Dog          165
# 1              Doctor         Reading      Cat          180
# 2              Artist        Painting     Fish          170
# 3                Chef         Cooking     Bird          175
# 4             Teacher       Gardening      NaN          160
# 5            Musician  Playing Guitar      Dog          185
# 6          Journalist         Writing   Rabbit          168
# 7             Student     Photography      NaN          163
# 8           Architect         Cycling      Cat          178
# 9            Designer          Gaming  Hamster          166
# 10           Mechanic     Fixing Cars      NaN          182
# 11              Nurse         Running      Dog          172
# 12             Dancer         Dancing      Cat          169
# 13             Writer       Traveling     Fish          176
# 14          Economist       Investing     Bird          164
# 15        Electrician     Woodworking      NaN          187
# 16       Veterinarian     Animal Care   Rabbit          171
# 17           Engineer      Meditation      Dog          179
# 18         Programmer     Calligraphy      Cat          162
# 19          Fisherman         Sailing      NaN          183
# 20         Accountant            Yoga      NaN          167
# 21  Marketing Manager         Cricket      Dog          174
# 22             Waiter         Cooking      NaN          177
#
#     Number of Siblings  Number of Children
# 0                    1                   0
# 1                    2                   1
# 2                    0                   0
# 3                    1                   2
# 4                    3                   0
# 5                    1                   1
# 6                    0                   2
# 7                    2                   0
# 8                    1                   3
# 9                    0                   1
# 10                   2                   0
# 11                   1                   2
# 12                   0                   0
# 13                   1                   1
# 14                   2                   0
# 15                   0                   2
# 16                   1                   0
# 17                   3                   1
# 18                   1                   0
# 19                   0                   2
# 20                   2                   0
# 21                   1                   0
# 22                   0                   1

# %% [markdown]
# ## Utility functions to get an overview of the data in the dataframe

# %%
df.head(3)  # default is first 5 lines if no value is provided
# Out:
#       Name      City  Birth Year Favorite Color Country of Birth  \
# 0    Alice  New York        1990           Blue              USA
# 1      Bob    London        1985          Green               UK
# 2  Charlie     Paris        1992            Red           France
#
#           Profession   Hobbies   Pet  Height (cm)  Number of Siblings  \
# 0  Software Engineer    Hiking   Dog          165                   1
# 1             Doctor   Reading   Cat          180                   2
# 2             Artist  Painting  Fish          170                   0
#
#    Number of Children
# 0                   0
# 1                   1
# 2                   0

# %%
df.tail(8) # default is last 5 lines if no argument provided
# Out:
#         Name       City  Birth Year Favorite Color Country of Birth  \
# 15     Peter     Berlin        1984         Violet          Germany
# 16     Quinn     London        1992            Red               UK
# 17     Rahul     Mumbai        1981         Orange            India
# 18       Mei   Shanghai        1990         Yellow            China
# 19      Sven  Stockholm        1987          Green           Sweden
# 20     Priya     Mumbai        1989           Blue            India
# 21     Arjun     Mumbai        1993         Indigo            India
# 22  Giuseppe       Rome        1986         Violet            Italy
#
#            Profession      Hobbies     Pet  Height (cm)  Number of Siblings  \
# 15        Electrician  Woodworking     NaN          187                   0
# 16       Veterinarian  Animal Care  Rabbit          171                   1
# 17           Engineer   Meditation     Dog          179                   3
# 18         Programmer  Calligraphy     Cat          162                   1
# 19          Fisherman      Sailing     NaN          183                   0
# 20         Accountant         Yoga     NaN          167                   2
# 21  Marketing Manager      Cricket     Dog          174                   1
# 22             Waiter      Cooking     NaN          177                   0
#
#     Number of Children
# 15                   2
# 16                   0
# 17                   1
# 18                   0
# 19                   2
# 20                   0
# 21                   0
# 22                   1

# %%
df.columns   # an (iterable) object with a list of all of the column names
# Out:
# Index(['Name', 'City', 'Birth Year', 'Favorite Color', 'Country of Birth',
#        'Profession', 'Hobbies', 'Pet', 'Height (cm)', 'Number of Siblings',
#        'Number of Children'],
#       dtype='object')

# %%
for c in df.columns:
    print(c)
# Out:
# Name
# City
# Birth Year
# Favorite Color
# Country of Birth
# Profession
# Hobbies
# Pet
# Height (cm)
# Number of Siblings
# Number of Children

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                23 non-null     object
#  1   City                23 non-null     object
#  2   Birth Year          23 non-null     int64
#  3   Favorite Color      23 non-null     object
#  4   Country of Birth    23 non-null     object
#  5   Profession          23 non-null     object
#  6   Hobbies             23 non-null     object
#  7   Pet                 16 non-null     object
#  8   Height (cm)         23 non-null     int64
#  9   Number of Siblings  23 non-null     int64
#  10  Number of Children  23 non-null     int64
# dtypes: int64(4), object(7)
# memory usage: 2.1+ KB

# %%
df.shape   # Shows number of rows and columns
# Out:
# (23, 11)

# %%
len(df)   # Shows number of rows
# Out:
# 23

# %%
df.describe()  # Provides statistical data for numeric columns
# Out:
#         Birth Year  Height (cm)  Number of Siblings  Number of Children
# count    23.000000    23.000000           23.000000           23.000000
# mean   1988.130435   172.739130            1.086957            0.826087
# std       4.256592     7.788204            0.949308            0.936734
# min    1980.000000   160.000000            0.000000            0.000000
# 25%    1985.500000   166.500000            0.000000            0.000000
# 50%    1989.000000   172.000000            1.000000            1.000000
# 75%    1991.500000   178.500000            2.000000            1.500000
# max    1995.000000   187.000000            3.000000            3.000000

# %% [markdown]
# ## Subsets of a Dataframe

# %%
# Select columns by name
selected_columns = ['Name','Birth Year','Country of Birth']
df[selected_columns].head()
# Out:
#       Name  Birth Year Country of Birth
# 0    Alice        1990              USA
# 1      Bob        1985               UK
# 2  Charlie        1992           France
# 3    David        1988            Japan
# 4      Eve        1991              USA

# %%
# Select column names numerically with slicing syntax
df.columns[0:5]
# Out:
# Index(['Name', 'City', 'Birth Year', 'Favorite Color', 'Country of Birth'], dtype='object')

# %%
# You can then use that to select dataframe columns 
df[df.columns[0:5]].head()
# Out:
#       Name      City  Birth Year Favorite Color Country of Birth
# 0    Alice  New York        1990           Blue              USA
# 1      Bob    London        1985          Green               UK
# 2  Charlie     Paris        1992            Red           France
# 3    David     Tokyo        1988         Indigo            Japan
# 4      Eve  New York        1991         Violet              USA

# %%
df[0:3]  # selects rows with slicing syntax
# Out:
#       Name      City  Birth Year Favorite Color Country of Birth  \
# 0    Alice  New York        1990           Blue              USA
# 1      Bob    London        1985          Green               UK
# 2  Charlie     Paris        1992            Red           France
#
#           Profession   Hobbies   Pet  Height (cm)  Number of Siblings  \
# 0  Software Engineer    Hiking   Dog          165                   1
# 1             Doctor   Reading   Cat          180                   2
# 2             Artist  Painting  Fish          170                   0
#
#    Number of Children
# 0                   0
# 1                   1
# 2                   0

# %%
# Conditions return a series of Boolean values
df['Birth Year']>1990
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# Name: Birth Year, dtype: bool

# %%
# Select based on a condition (the series from the conditional)
df[df['Birth Year']>1990]
# Out:
#        Name      City  Birth Year Favorite Color Country of Birth  \
# 2   Charlie     Paris        1992            Red           France
# 4       Eve  New York        1991         Violet              USA
# 7     Heidi     Paris        1994           Blue           France
# 10    Kevin    Berlin        1993         Orange          Germany
# 12      Mia  New York        1995          Green              USA
# 16    Quinn    London        1992            Red               UK
# 21    Arjun    Mumbai        1993         Indigo            India
#
#            Profession      Hobbies     Pet  Height (cm)  Number of Siblings  \
# 2              Artist     Painting    Fish          170                   0
# 4             Teacher    Gardening     NaN          160                   3
# 7             Student  Photography     NaN          163                   2
# 10           Mechanic  Fixing Cars     NaN          182                   2
# 12             Dancer      Dancing     Cat          169                   0
# 16       Veterinarian  Animal Care  Rabbit          171                   1
# 21  Marketing Manager      Cricket     Dog          174                   1
#
#     Number of Children
# 2                    0
# 4                    0
# 7                    0
# 10                   0
# 12                   0
# 16                   0
# 21                   0

# %% [markdown]
# One can also select based on multiple conditions. Be careful to use `&` (element-wise "and") and not `and`...

# %%
# Select based on condition
df[(df['Birth Year']>1990) & (df['Favorite Color']=='Red')]
# Out:
#        Name    City  Birth Year Favorite Color Country of Birth    Profession  \
# 2   Charlie   Paris        1992            Red           France        Artist
# 16    Quinn  London        1992            Red               UK  Veterinarian
#
#         Hobbies     Pet  Height (cm)  Number of Siblings  Number of Children
# 2      Painting    Fish          170                   0                   0
# 16  Animal Care  Rabbit          171                   1                   0

# %% [markdown]
# # TO ADD: iloc and loc

# %% [markdown]
# ## Plotting data from a Pandas dataframe

# %%
#plt.scatter(df['Birth Year'],df['Number of Children'])
#plt.hist(df['Birth Year'])
###plt.hist(df['Favorite Color'],bins=['Red', 'Orange', 'Yellow', 'Green', 'Blue', 'Indigo', 'Violet'])

# %%
# Add a new column
df['Height (m)'] = df['Height (cm)'] / 100
df
# Out:
#         Name       City  Birth Year Favorite Color Country of Birth  \
# 0      Alice   New York        1990           Blue              USA
# 1        Bob     London        1985          Green               UK
# 2    Charlie      Paris        1992            Red           France
# 3      David      Tokyo        1988         Indigo            Japan
# 4        Eve   New York        1991         Violet              USA
# 5      Frank     Berlin        1983         Orange          Germany
# 6      Grace     London        1987         Yellow               UK
# 7      Heidi      Paris        1994           Blue           France
# 8       Ivan   New York        1980          Green              USA
# 9       Judy      Tokyo        1989            Red            Japan
# 10     Kevin     Berlin        1993         Orange          Germany
# 11      Liam     London        1986         Yellow               UK
# 12       Mia   New York        1995          Green              USA
# 13      Noah      Paris        1982           Blue           France
# 14    Olivia      Tokyo        1990         Indigo            Japan
# 15     Peter     Berlin        1984         Violet          Germany
# 16     Quinn     London        1992            Red               UK
# 17     Rahul     Mumbai        1981         Orange            India
# 18       Mei   Shanghai        1990         Yellow            China
# 19      Sven  Stockholm        1987          Green           Sweden
# 20     Priya     Mumbai        1989           Blue            India
# 21     Arjun     Mumbai        1993         Indigo            India
# 22  Giuseppe       Rome        1986         Violet            Italy
#
#            Profession         Hobbies      Pet  Height (cm)  \
# 0   Software Engineer          Hiking      Dog          165
# 1              Doctor         Reading      Cat          180
# 2              Artist        Painting     Fish          170
# 3                Chef         Cooking     Bird          175
# 4             Teacher       Gardening      NaN          160
# 5            Musician  Playing Guitar      Dog          185
# 6          Journalist         Writing   Rabbit          168
# 7             Student     Photography      NaN          163
# 8           Architect         Cycling      Cat          178
# 9            Designer          Gaming  Hamster          166
# 10           Mechanic     Fixing Cars      NaN          182
# 11              Nurse         Running      Dog          172
# 12             Dancer         Dancing      Cat          169
# 13             Writer       Traveling     Fish          176
# 14          Economist       Investing     Bird          164
# 15        Electrician     Woodworking      NaN          187
# 16       Veterinarian     Animal Care   Rabbit          171
# 17           Engineer      Meditation      Dog          179
# 18         Programmer     Calligraphy      Cat          162
# 19          Fisherman         Sailing      NaN          183
# 20         Accountant            Yoga      NaN          167
# 21  Marketing Manager         Cricket      Dog          174
# 22             Waiter         Cooking      NaN          177
#
#     Number of Siblings  Number of Children  Height (m)
# 0                    1                   0        1.65
# 1                    2                   1        1.80
# 2                    0                   0        1.70
# 3                    1                   2        1.75
# 4                    3                   0        1.60
# 5                    1                   1        1.85
# 6                    0                   2        1.68
# 7                    2                   0        1.63
# 8                    1                   3        1.78
# 9                    0                   1        1.66
# 10                   2                   0        1.82
# 11                   1                   2        1.72
# 12                   0                   0        1.69
# 13                   1                   1        1.76
# 14                   2                   0        1.64
# 15                   0                   2        1.87
# 16                   1                   0        1.71
# 17                   3                   1        1.79
# 18                   1                   0        1.62
# 19                   0                   2        1.83
# 20                   2                   0        1.67
# 21                   1                   0        1.74
# 22                   0                   1        1.77

# %%
# Make a copy of the dataframe with only selected columns -and- rename some columns
columns = ['Name','City','Height (m)', 'Birth Year']
df2 = df[columns].copy().rename(columns={'Birth Year':'Year','Height (m)':'Height'})
df2
# Out:
#         Name       City  Height  Year
# 0      Alice   New York    1.65  1990
# 1        Bob     London    1.80  1985
# 2    Charlie      Paris    1.70  1992
# 3      David      Tokyo    1.75  1988
# 4        Eve   New York    1.60  1991
# 5      Frank     Berlin    1.85  1983
# 6      Grace     London    1.68  1987
# 7      Heidi      Paris    1.63  1994
# 8       Ivan   New York    1.78  1980
# 9       Judy      Tokyo    1.66  1989
# 10     Kevin     Berlin    1.82  1993
# 11      Liam     London    1.72  1986
# 12       Mia   New York    1.69  1995
# 13      Noah      Paris    1.76  1982
# 14    Olivia      Tokyo    1.64  1990
# 15     Peter     Berlin    1.87  1984
# 16     Quinn     London    1.71  1992
# 17     Rahul     Mumbai    1.79  1981
# 18       Mei   Shanghai    1.62  1990
# 19      Sven  Stockholm    1.83  1987
# 20     Priya     Mumbai    1.67  1989
# 21     Arjun     Mumbai    1.74  1993
# 22  Giuseppe       Rome    1.77  1986

# %% [markdown]
# ## Creating and Modifying Dataframes
#
# You can create a dataframe from a dictionary of lists

# %% [markdown]
# ## How to understand a dataset you load in Pandas
#
#   If you load a new (to you) dataset in Pandas, typically the useful things to do are:
#
#   * do df.head() to get a quick sense what is there
#   * understand what the rows are
#   * understand what columns are available (by column names or by separate documentation)
#     * df.columns and df.dtypes
#   * drop any columns you do not need
#   * understand if the data is complete or if some elements are missing
#   * df['foo'].value_counts()
#   * df.isna().sum()
